# %% [markdown]
# <a href="https://colab.research.google.com/github/Mukesh-V-AI/deep-learning-laboratory/blob/main/dl_exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Neural Network WITHOUT Regularization

# %%
model_base = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model_base.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_base = model_base.fit(
    X_train, y_train,
    epochs=10,
    validation_split=0.2,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8647 - loss: 0.4787 - val_accuracy: 0.9551 - val_loss: 0.1552
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9614 - loss: 0.1317 - val_accuracy: 0.9668 - val_loss: 0.1123
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9734 - loss: 0.0891 - val_accuracy: 0.9668 - val_loss: 0.1123
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9819 - loss: 0.0615 - val_accuracy: 0.9747 - val_loss: 0.0894
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9853 - loss: 0.0501 - val_accuracy: 0.9707 - val_loss: 0.1016
# Epoch 6/10
# ...

# %% [markdown]
# Neural Network WITH L2 Regularization

# %%
model_l2 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    Dense(10, activation='softmax')
])

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_l2 = model_l2.fit(
    X_train, y_train,
    epochs=10,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8646 - loss: 0.6172 - val_accuracy: 0.9485 - val_loss: 0.2741
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9502 - loss: 0.2603 - val_accuracy: 0.9617 - val_loss: 0.2225
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9614 - loss: 0.2181 - val_accuracy: 0.9621 - val_loss: 0.2088
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9650 - loss: 0.1981 - val_accuracy: 0.9672 - val_loss: 0.1904
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9694 - loss: 0.1818 - val_accuracy: 0.9666 - val_loss: 0.1914
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9712 - loss: 0.1734 - val_accuracy: 0.9711 - val_loss: 0.1741
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9726 - loss: 0.1681 - val_accuracy: 0.9715 - val_loss: 0.1694
# Epoch 8/10
# ...

# %% [markdown]
# Neural Network WITH L1 Regularization

# %%
model_l1 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu', kernel_regularizer=l1(0.001)),
    Dense(10, activation='softmax')
])

model_l1.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_l1 = model_l1.fit(
    X_train, y_train,
    epochs=10,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8315 - loss: 1.6555 - val_accuracy: 0.9160 - val_loss: 0.6533
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9065 - loss: 0.6490 - val_accuracy: 0.9319 - val_loss: 0.5388
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9193 - loss: 0.5623 - val_accuracy: 0.9408 - val_loss: 0.4866
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9303 - loss: 0.5028 - val_accuracy: 0.9338 - val_loss: 0.4941
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9380 - loss: 0.4679 - val_accuracy: 0.9449 - val_loss: 0.4233
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9418 - loss: 0.4431 - val_accuracy: 0.9497 - val_loss: 0.4052
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9438 - loss: 0.4215 - val_accuracy: 0.9519 - val_loss: 0.3914
# Epoch 8/10
# ...

# %%
plt.plot(history_base.history['val_accuracy'], label='No Regularization')
plt.plot(history_l2.history['val_accuracy'], label='L2 Regularization')
plt.plot(history_l1.history['val_accuracy'], label='L1 Regularization')

plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.title('Validation Accuracy Comparison')
plt.show()
